# %% [markdown]
# PREGUNTAS

# %%
import pandas as pd
import numpy as np
import io as io
import requests as r
pd.set_option('display.float_format', lambda x: '%.2f' % x) # truco para notación cientifica

# %% [markdown]
# 1. ¿Está su API actualizada? ,¿cuántos productos faltan? JC

# %% [markdown]
# 2. ¿Cuál es la diferencia media de sus precios vs los precios de Carrefour?

# %% [markdown]
# 3. ¿Cómo me posiciono según precio y variedad de productos en las principales categorías con respecto a todas las marcas?

# %% [markdown]
# 4. ¿Cuál es el producto en el que somos más caros ?, ¿y el más barato?

# %% [markdown]
# 5. Actualmente queremos destinar dinero para igualar los mejores precios de la competencia. ¿Cuál es la cantidad total a invertir?

# %% [markdown]
# 6. ¿Hay algún precio de nuestros productos que no siga la tendencia de la competencia, ¿por qué podría ser?

# %% [markdown]
# 7. ¿Hay algún precio de nuestros productos que no siga la tendencia de la competencia, ¿por qué podría ser?

# %% [markdown]
# 8. ¿Cuántas marcas blancas tiene mi competencia? , ¿estamos mejor o peor posicionados según precio y variedad?

# %% [markdown]
# 9. ¿Hay alguna categoría que quitarías o añadirías?, ¿por qué?.

# %% [markdown]
# 10. Estamos pensando en abrir una nueva vertical llamada Mercadona eat&go. Su objetivo es que la gente pueda comprar y comer los productos en una sala acondicionada dentro de nuestro establecimiento. Te compartimos un csv con las compras de algunos usuarios en vera qno. ¿Qué tipo de alimentos recomendarías y por qué?

# %% [markdown]
# 4. ¿Cuál es el producto en el que somos más caros ?, ¿y el más barato?
# El producto más caro es Carabinero congelado.
# El producto más barato son la unidad de Bolitas de coco Antiu Xixona.

# %% [markdown]
# #ID,Name
# #M1,Mercadona
# #M2,Carrefour
# #M3,Dia

# %%
dfraw= pd.read_csv(r"C:\Users\msanf\Desktop\Fuentes de datos\raw_data_scrapper\raw_data.csv")

# %%
dfraw.head(3)
# Out:
#                                             category  \
# 0  perfumeria_e_higiene_cuidado_facial_protector_...
# 1      perfumeria_e_higiene_higiene_intima_compresas
# 2      perfumeria_e_higiene_higiene_intima_compresas
#
#                                                 name description  price  \
# 0     LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
# 1         AUSONIA compresas normal alas bolsa 14 uds         NaN   2.49
# 2  EVAX Cottonlike compresa super plus con alas b...         NaN   2.79
#
#    reference_price reference_unit          insert_date  \
# 0             2.39             ud  2021-03-06 00:00:00
# 1             0.18             ud  2021-03-06 00:00:00
# 2             0.23             ud  2021-03-06 00:00:00
#
#                          product_id id_reference_supermarket
# 0  45d83ce427cf60c02e1e6f3d28f58ed6                       M3
# 1  3fa10738dcbe5f09646eaf39a46a2871                       M3
# ...

# %%
dfraw.describe()
# Out:
#            price  reference_price
# count 8223974.00       8223986.00
# mean        4.75            19.35
# std        48.90           626.79
# min         0.08             0.00
# 25%         1.39             1.80
# 50%         2.20             4.56
# 75%         3.99             9.92
# max      7915.05        163333.33

# %%
dfraw.sort_values(by='price', ascending=False)
# Out:
#                                       category  \
# 1811852                     congelados_marisco
# 2031938                     congelados_marisco
# 1793873                     congelados_marisco
# 2444898                     congelados_marisco
# 1337397                     congelados_marisco
# ...                                        ...
# 7454632  bebidas_alcoholes_todos_los_alcoholes
# 7470900  bebidas_alcoholes_todos_los_alcoholes
# 7494688  bebidas_alcoholes_todos_los_alcoholes
# 7503013  bebidas_alcoholes_todos_los_alcoholes
# 7519678  bebidas_alcoholes_todos_los_alcoholes
#
#                                    name description   price  reference_price  \
# 1811852            Carabinero congelado      Granel 7915.05            79.95
# 2031938            Carabinero congelado      Granel 7915.05            79.95
# 1793873            Carabinero congelado      Granel 7915.05            79.95
# 2444898            Carabinero congelado      Granel 7915.05            79.95
# ...

# %%
dfraw.sort_values(by='price', ascending=True)
# Out:
#                                          category  \
# 3855368  panaderia_y_pasteleria_bolleria_envasada
# 4084149  panaderia_y_pasteleria_bolleria_envasada
# 4604012  panaderia_y_pasteleria_bolleria_envasada
# 4592867  panaderia_y_pasteleria_bolleria_envasada
# 4709837                dulces_de_navidad_turrones
# ...                                           ...
# 7454632     bebidas_alcoholes_todos_los_alcoholes
# 7470900     bebidas_alcoholes_todos_los_alcoholes
# 7494688     bebidas_alcoholes_todos_los_alcoholes
# 7503013     bebidas_alcoholes_todos_los_alcoholes
# 7519678     bebidas_alcoholes_todos_los_alcoholes
#
#                                                   name description  price  \
# 3855368                   Bolitas de coco Antiu Xixona         NaN   0.08
# 4084149                   Bolitas de coco Antiu Xixona         NaN   0.08
# 4604012                   Bolitas de coco Antiu Xixona         NaN   0.08
# ...

# %%
dfraw.shape
# Out:
# (8223992, 9)

# %%
#dfs_c=Super_competitors.csv

#dfs_c= pd.read_csv(r"C:\Users\msanf\Desktop\Fuentes de datos\Super_competitors.csv")
dfs_c= pd.read_excel(r"C:\Users\msanf\Desktop\Fuentes de datos\Super_competitors_excel.xlsx")

# %%
dfs_c.head()
# Out:
#         ID,Name
# 0  M1,Mercadona
# 1  M2,Carrefour
# 2        M3,Dia

# %%
dfs_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID,Name  3 non-null      object
# dtypes: object(1)
# memory usage: 152.0+ bytes

# %%
dfs_c.columns.values.tolist()
# Out:
# ['ID,Name']

# %%
dfs_c= dfs_c.rename(columns= {"ID,Name" : "Supermercado"})

# %%
dfs_c.head()
# Out:
#    Supermercado
# 0  M1,Mercadona
# 1  M2,Carrefour
# 2        M3,Dia

# %%
dfs_c.dtypes
# Out:
# Supermercado    object
# dtype: object

# %%
dfs_c.replace(',', '')
# Out:
#    Supermercado
# 0  M1,Mercadona
# 1  M2,Carrefour
# 2        M3,Dia

# %%
df_merged_raw_s_c = dfraw.merge(dfs_c, how = "left" , left_on = "id_reference_supermarket" , right_on = "Supermercado" )

# %%
df_merged_raw_s_c.head(5)
# Out:
#                                             category  \
# 0  perfumeria_e_higiene_cuidado_facial_protector_...
# 1      perfumeria_e_higiene_higiene_intima_compresas
# 2      perfumeria_e_higiene_higiene_intima_compresas
# 3  perfumeria_e_higiene_higiene_bucal_productos_p...
# 4  perfumeria_e_higiene_higiene_bucal_productos_p...
#
#                                                 name description  price  \
# 0     LIPOSAN protector labial soft rose envase 1 ud         NaN   2.39
# 1         AUSONIA compresas normal alas bolsa 14 uds         NaN   2.49
# 2  EVAX Cottonlike compresa super plus con alas b...         NaN   2.79
# 3  POLIDENT tabletas limpiadoras para prótesis de...         NaN   7.95
# 4  IWHITE kit de blanquamiento dental profesional...         NaN  36.99
#
#    reference_price reference_unit          insert_date  \
# 0             2.39             ud  2021-03-06 00:00:00
# 1             0.18             ud  2021-03-06 00:00:00
# ...

# %%
#dfdata=datamarket_productos_de_supermercados.csv
#dfdata= pd.read_csv(r"C:\Users\msanf\Desktop\Fuentes de datos\datamarket_productos_de_supermercados.csv")

# %%
#dfdata.head(8)
# Out:
#                                                  url   supermarket  \
# 0  https://tienda.mercadona.es/product/2839/pinch...  mercadona-es
# 1  https://tienda.mercadona.es/product/4917/solom...  mercadona-es
# 2  https://tienda.mercadona.es/product/2858/sesos...  mercadona-es
# 3  https://tienda.mercadona.es/product/4919/secre...  mercadona-es
# 4  https://tienda.mercadona.es/product/1886/lomo-...  mercadona-es
# 5  https://tienda.mercadona.es/product/4915/presa...  mercadona-es
# 6  https://tienda.mercadona.es/product/2678/libri...  mercadona-es
# 7  https://tienda.mercadona.es/product/3557/costi...  mercadona-es
#
#       category                           name description  price  \
# 0  carne_cerdo   Pinchos de cerdo sin varilla     Bandeja   4.21
# 1  carne_cerdo     Solomillo de cerdo ibérico     Bandeja   6.62
# 2  carne_cerdo                 Sesos de cerdo     Bandeja   1.80
# 3  carne_cerdo       Secreto de cerdo ibérico     Bandeja   4.04
# ...

# %%
#dfsdata.shape
# Out:
# (9054122, 10)

# %%
#dfcompras=df_compras_100000.csv
dfcompras= pd.read_csv(r"C:\Users\msanf\Desktop\Fuentes de datos\df_compras_100000.csv")

# %%
dfcompras.head(5)
# Out:
#    id_compra fecha_compra  id_cliente                       id_producto
# 0          0   2022-06-02          19  f65b04468e58cc9f604cb097236872fe
# 1          1   2022-08-02          27  ce43ded19a577ac0aaa1e3b0cf2b5f1a
# 2          2   2022-07-09          20  0a56c32642021feae8049bbb840a6153
# 3          3   2022-08-18           5  2f8af1c55f93e0b3e4a0b03e5e0f28b4
# 4          4   2022-06-27           3  d7382d624ca08e4459996938e65935e8

# %%
dfcompras.shape
# Out:
# (100000, 4)
